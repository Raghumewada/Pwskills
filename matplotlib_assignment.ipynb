# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [raw]
# Matplotlib is a Python library used for creating various types of plots and visualizations. It's widely used in data analysis, scientific research, and other fields where data visualization is crucial. Some common plots that can be created using the Pyplot module of Matplotlib include:
#
# Line plot
# Histogram
# Scatter plot
# Bar plot
# Pie chart

# %% [raw]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [raw]
# A scatter plot is a type of graphical representation used to display the relationship between two continuous variables. Each data point in the plot represents the value of one variable plotted on the x-axis and the value of the other variable plotted on the y-axis.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("random data")
plt.show()

# %% [raw]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(4,1,1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(4,1,2)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(4,1,3)
plt.plot(x,y)
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(4,1,4)
plt.plot(x,y)

# %% [raw]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])

# %% [raw]
# A bar plot is a graphical representation of categorical data using rectangular bars. The length of each bar corresponds to the frequency or proportion of data within each category

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.xlabel("company name")
plt.ylabel("profit ")
plt.title("company data")
plt.show()

# %%
plt.barh(company,profit)
plt.xlabel("company name")
plt.ylabel("profit ")
plt.title("company data")
plt.show()

# %% [raw]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [raw]
# A box plot, also known as a box-and-whisker plot, is a graphical representation that displays the distribution of a dataset along a single axis. It summarizes key features of the dataset, such as the median, quartiles, and potential outliers.
#
# It's used to:
#
# Visualize Spread: Show the spread of the data, including the range, quartiles, and interquartile range (IQR).
#
# Identify Outliers: Easily identify potential outliers in the dataset.
#
# Compare Distributions: Compare the distributions of different datasets or variables.
#
# Understand Central Tendency: Display the median and quartiles, providing insights into the central tendency and variability of the data.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot(box1,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff4f1b66fe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff4f1b67520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff4f1b66d40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff4f1b67a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff4f1b67d00>],
#  'means': []}

# %%
plt.boxplot(box2,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ff4f19e18d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ff4f19e1e10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ff4f19e1630>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff4f19e2350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff4f19e25f0>],
#  'means': []}
