# %% [markdown]
# Q1. Explain the basic concept of clustering and give examples of applications where clustering is useful.

# %% [markdown]
# - Definition: Clustering is the process of grouping similar data points together based on their features.
# - Examples of Applications:
#     - Customer segmentation in marketing.
#     - Document clustering in information retrieval.
#     - Image segmentation in computer vision.
#     - Anomaly detection in fraud detection.

# %% [markdown]
# Q2. What is DBSCAN and how does it differ from other clustering algorithms such as k-means and
# hierarchical clustering?

# %% [markdown]
# - Definition: DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a clustering algorithm that identifies clusters based on the density of points.
# - Differences from K-means and Hierarchical Clustering:
#     - Does not require specifying the number of clusters in advance.
#     - Can find arbitrarily shaped clusters.
#     - Identifies outliers as noise.

# %% [markdown]
# Q3. How do you determine the optimal values for the epsilon and minimum points parameters in DBSCAN
# clustering?

# %% [markdown]
# Methods:
# - Epsilon (ε): Use a k-distance plot to find the distance where a significant change occurs.
# - Minimum Points (minPts): Commonly set as twice the number of dimensions or use domain knowledge.

# %% [markdown]
# Q4. How does DBSCAN clustering handle outliers in a dataset?

# %% [markdown]
# Method: Points that do not belong to any cluster (fewer than minPts within distance ε) are classified as noise or outliers.

# %% [markdown]
# Q5. How does DBSCAN clustering differ from k-means clustering?

# %% [markdown]
# K-means:
#
# - Requires pre-specifying the number of clusters (k).
# - Assumes spherical clusters of similar sizes.
# - Sensitive to initial centroid positions.
#
# DBSCAN:
#
# - Does not require specifying the number of clusters.
# - Can find clusters of arbitrary shapes and sizes.
# - Identifies outliers as noise.

# %% [markdown]
# Q6. Can DBSCAN clustering be applied to datasets with high dimensional feature spaces? If so, what are
# some potential challenges?

# %% [markdown]
# - Application: Yes, it can be applied.
# - Challenges: Curse of dimensionality makes distance measures less meaningful, leading to difficulty in setting ε and minPts.

# %% [markdown]
# Q7. How does DBSCAN clustering handle clusters with varying densities?

# %% [markdown]
# Method: DBSCAN may struggle with varying densities since it uses a global ε and minPts. However, OPTICS (Ordering Points To Identify the Clustering Structure) is a related algorithm that addresses this.

# %% [markdown]
# Q8. What are some common evaluation metrics used to assess the quality of DBSCAN clustering results?

# %% [markdown]
# Common Metrics:
# - Silhouette Score.
# - Davies-Bouldin Index.
# - Adjusted Rand Index (for comparing with ground truth).
# - Number of clusters and noise points.

# %% [markdown]
# Q9. Can DBSCAN clustering be used for semi-supervised learning tasks?

# %% [markdown]
# Application: Yes, can be used to identify clusters in labeled and unlabeled data, then propagate labels from high-density clusters to nearby points.

# %% [markdown]
# Q10. How does DBSCAN clustering handle datasets with noise or missing values?

# %% [markdown]
# - Noise: Identifies and labels outliers as noise.
# - Missing Values: Usually require preprocessing (imputation or removal) before applying DBSCAN.

# %% [markdown]
# Q11. Implement the DBSCAN algorithm using a python programming language, and apply it to a sample
# dataset. Discuss the clustering results and interpret the meaning of the obtained clusters.

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# Create sample data
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.5, random_state=0)

# Apply DBSCAN
dbscan = DBSCAN(eps=0.3, min_samples=10)
clusters = dbscan.fit_predict(X)

# Plot results
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='viridis')
plt.title('DBSCAN Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# Clustering Results Interpretation:
# - Each color represents a different cluster.
# - Points labeled -1 are considered noise or outliers.
# - Insights can be derived by analyzing the distribution and density of the clusters, identifying patterns, and understanding the underlying data structure.
